# %%
def main():
    tasks = []
    while True:
        print("\nTo Do List")
        print("1. Add Task")
        print("2. Show Tasks")
        print("3. Mark as Done")
        print("4. Exit")
        
        choice = input("Enter your choice: ")
        
        if choice == '1':
            print()
            try:
                n_tasks = int(input("How many tasks do you need to add: "))
                for _ in range(n_tasks):
                    task = input("Enter the task: ")
                    tasks.append({"task": task, "done": False})
                    print("Task added.")
            except ValueError:
                print("Invalid number. Please enter an integer.")
        elif choice == '2':
            if tasks:
                print("\nTasks:")
                for index, task in enumerate(tasks):
                    status = "Done" if task["done"] else "Not done"
                    print(f"{index + 1}. {task['task']} - {status}")
            else:
                print("\nNo tasks to show.")
        elif choice == '3':
            if tasks:
                try:
                    task_index = int(input("Enter the task number to mark as done: ")) - 1
                    if 0 <= task_index < len(tasks):
                        tasks[task_index]["done"] = True
                        print("Task marked as done.")
                    else:
                        print("Invalid task number.")
                except ValueError:
                    print("Invalid input. Please enter an integer.")
            else:
                print("No tasks to mark as done.")
        elif choice == '4':
            print("Exiting from To Do List")
            break
        else:
            print("Invalid choice! Please try again.")

if __name__ == "__main__":
    main()
# Out:
# To Do List
# 1. Add Task
# 2. Show Tasks
# 3. Mark as Done
# 4. Exit
# Enter your choice: 1
#
# How many tasks do you need to add: 5
# Enter the task: Reading
# Task added.
# Enter the task: Writing
# Task added.
# Enter the task: Playing
# Task added.
# Enter the task: Excercise
# Task added.
# Enter the task: Study
# Task added.
#
# To Do List
# 1. Add Task
# 2. Show Tasks
# 3. Mark as Done
# 4. Exit
# Enter your choice: 2
#
# Tasks:
# 1. Reading - Not done
# 2. Writing - Not done
# 3. Playing - Not done
# 4. Excercise - Not done
# 5. Study - Not done
#
# To Do List
# 1. Add Task
# 2. Show Tasks
# 3. Mark as Done
# 4. Exit
# Enter your choice: 3
# Enter the task number to mark as done: 3
# Task marked as done.
#
# To Do List
# 1. Add Task
# 2. Show Tasks
# 3. Mark as Done
# 4. Exit
# Enter your choice: 2
#
# Tasks:
# 1. Reading - Not done
# 2. Writing - Not done
# 3. Playing - Done
# 4. Excercise - Not done
# 5. Study - Not done
#
# To Do List
# 1. Add Task
# 2. Show Tasks
# 3. Mark as Done
# 4. Exit
# Enter your choice: 4
# Exiting from To Do List
